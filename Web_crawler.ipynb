# %% [markdown]
# <a href="https://colab.research.google.com/github/KY9799302/KY9799302/blob/main/Web_crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests 
from lxml import html
url = "https://sitchu.com.au/Sydney/beauty/best-autralian-skincare-brands"
page = requests.Session().get(url)
tree = html.fromstring(page.text)
result = tree.xpath('//td[@class ="title"]//a/text()')
# Out:
# []
# <Response [404]>
# https://sitchu.com.au/Sydney/beauty/best-autralian-skincare-brands

# %%
from urllib import request
req = request.urlopen("https://sitchu.com.au/")
print(req.read().decode())
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <title> Sitchu | Best Suburbs in  | Be you. Live Local. </title>
#     <!--[if IE]>
#     <meta http-equiv="imagetoolbar" content="no" />
#     <![endif]-->
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta name="viewport" id="vport" content="width=device-width, initial-scale=1, user-scalable=no" />
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/public/img/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/public/img/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/public/img/favicon-16x16.png">
#     <link rel="manifest" href="/public/img/site.webmanifest">
#     <link rel="mask-icon" href="/public/img/safari-pinned-tab.svg" color="#40413e">
#     <link rel="shortcut icon" href="/public/img/favicon.ico">
#     <meta name="apple-mobile-web-app-title" content="Sitchu">
# ...
